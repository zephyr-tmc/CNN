# %%
import numpy as np
import tensorflow as tf
from IPython.display import display
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# 2024-08-03 03:16:54.634191: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-03 03:16:54.669803: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-03 03:16:54.669833: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-03 03:16:54.670736: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
def load_model():
    model = tf.keras.models.load_model('/home/jovyan/work/1/model2.h5')  # path
    return model
model = load_model()
# Out:
# 2024-08-03 03:17:00.563102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7910 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 1g.10gb, pci bus id: 0000:56:00.0, compute capability: 8.0

# %%
def predict_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150)) 
    image_array = np.array(image) / 255.0  
    image_array = np.expand_dims(image_array, axis=0)  

    # モデルを使う予測する
    prediction = model.predict(image_array)
    pred_label = 'dog' if prediction[0] > 0.5 else 'cat'
    
    # 図と予測結果を示す
    plt.imshow(image)
    plt.title(f'Prediction: {pred_label}')
    plt.axis('off')  
    plt.show()

# %%
# path
image_path = '/home/jovyan/work/1/image1.jpeg'  
predict_image(image_path)
# Out:
# 2024-08-03 03:17:16.232593: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 1/1 [==============================] - 3s 3s/step

# %%
# path
image_path = '/home/jovyan/work/1/image2.jpg'  
predict_image(image_path)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
# path
image_path = '/home/jovyan/work/1/image3.jpeg'  
predict_image(image_path)
# Out:
# 1/1 [==============================] - 0s 25ms/step
